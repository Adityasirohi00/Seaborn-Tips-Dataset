# %%
pip install seaborn

# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
import matplotlib.pyplot as plt

# %%
sns.histplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=df,x='tip')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=df,x='size')
# Out:
# <Axes: xlabel='size', ylabel='Count'>

# %%
sns.boxplot(data=df,x='total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.countplot(data=df,x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
# plt.figure(figsize=(5,5))
# plt.pie(df['sex'].value_counts(), labels=['Male','Female'],autopct='%1.1f%%',shadow=True,explode=[0.08,0])
# plt.show()

# %%
label_df=df['sex'].value_counts().index

# %%
label_df=df['sex'].value_counts().values

# %%
plt.pie(label_df,labels=label_df,autopct='%1.1f%%',shadow=True,explode=[0.08,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x78b7baad9d10>,
# ...
#  [Text(-0.5139376039169379, 1.0621996701562832, '157'),
#   Text(0.47909422701878684, -0.990186205537762, '87')],
#  [Text(-0.296167432765693, 0.612115064157858, '64.3%'),
#   Text(0.2613241238284292, -0.5401015666569611, '35.7%')])

# %%
sns.barplot(data=df,x='sex',y='total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(data=df,x='sex',y='total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.scatterplot(data=df,x='tip',y='total_bill')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
df[['tip','total_bill','size']].corr()
# Out:
#                  tip  total_bill      size
# tip         1.000000    0.675734  0.489299
# total_bill  0.675734    1.000000  0.598315
# size        0.489299    0.598315  1.000000

# %%
# prompt: heatmap

import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is already loaded as in your previous code
# If not, uncomment the line below:
# df = sns.load_dataset('tips')

sns.heatmap(df[['tip','total_bill','size']].corr(),annot=True)
plt.show()

# %%
# prompt: annotation

import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is already loaded as in your previous code
# If not, uncomment the line below:
# df = sns.load_dataset('tips')

sns.heatmap(df[['tip','total_bill','size']].corr(),annot=True) # annot=True displays the correlation values within the heatmap cells.
plt.show()

# %%
sns.pairplot(data=df)

# %%
sns.scatterplot(data=df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(data=df,x='sex',y='total_bill',hue='time')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(data=df,x='sex',y='tip',hue='time')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(data=df,x='sex',y='total_bill',hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
from sklearn.svm import SVR

# %%
model=SVR()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['sex']=le.fit_transform(df['sex'])

# %%
df['smoker']=le.fit_transform(df['smoker'])

# %%
df['day']=le.fit_transform(df['day'])

# %%
df['time']=le.fit_transform(df['time'])

# %%
df
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    2     0     2
# 1         10.34  1.66    1       0    2     0     3
# 2         21.01  3.50    1       0    2     0     3
# 3         23.68  3.31    1       0    2     0     2
# 4         24.59  3.61    0       0    2     0     4
# ..          ...   ...  ...     ...  ...   ...   ...
# 239       29.03  5.92    1       0    1     0     3
# 240       27.18  2.00    0       1    1     0     2
# 241       22.67  2.00    1       1    1     0     2
# 242       17.82  1.75    1       0    1     0     2
# 243       18.78  3.00    0       0    3     0     2
#
# [244 rows x 7 columns]

# %%
x=df.drop('total_bill',axis=1)

# %%
y=df['total_bill']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.33, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# SVR()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([17.23776951, 13.91004195, 19.07587387, 27.97747147, 14.61908728,
#        14.62784194, 16.16827462, 15.12604376, 17.62467719, 17.14407972,
#        16.79109742, 12.79083275, 13.39995535, 14.62784194, 13.47764856,
#        15.07492102, 22.22637113, 20.25127145, 14.81883713, 27.25097761,
#        20.00543459, 20.31991045, 20.54771542, 12.77154771, 21.29884935,
#        14.97341455, 13.39516952, 23.76068919, 19.07587387, 27.50372168,
#        23.03038906, 13.34266524, 19.65404079, 17.79350459, 21.06280904,
#        20.98656298, 13.93258919, 26.23727111, 15.73872234, 14.20246889,
#        12.62633449, 14.02203745, 15.31297738, 15.37437518, 15.05008891,
#        12.86339051, 13.46690746, 16.65401733, 13.71277993, 15.59327026,
#        14.26554037, 20.527115  , 26.81406373, 14.42703312, 18.68091909,
#        14.37601362, 24.30369872, 13.15140716, 18.29454924, 19.41114752,
#        28.71883072, 18.54346294, 25.32631104, 15.02703377, 13.63420889,
# ...

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5015773574264557

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 4.318138322667473

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 37.09625598971159

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
obj1=KNeighborsRegressor()

# %%
obj1.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()
